# %%
DATASET = r"../dataset/splitted"

# %%
import os
def walk_through_dir(dir_path):
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

walk_through_dir(DATASET)
# Out:
# There are 2 directories and 0 images in '../dataset/splitted'.
# There are 6 directories and 0 images in '../dataset/splitted\test'.
# There are 0 directories and 150 images in '../dataset/splitted\test\Gilmore'.
# There are 0 directories and 150 images in '../dataset/splitted\test\Golden Boy'.
# There are 0 directories and 150 images in '../dataset/splitted\test\Golden Boy x Gilmore'.
# There are 0 directories and 150 images in '../dataset/splitted\test\Golden Boy x Harold Brown'.
# There are 0 directories and 150 images in '../dataset/splitted\test\Harold Brown'.
# There are 0 directories and 150 images in '../dataset/splitted\test\Kearny'.
# There are 6 directories and 0 images in '../dataset/splitted\train'.
# There are 0 directories and 350 images in '../dataset/splitted\train\Gilmore'.
# There are 0 directories and 350 images in '../dataset/splitted\train\Golden Boy'.
# There are 0 directories and 350 images in '../dataset/splitted\train\Golden Boy x Gilmore'.
# There are 0 directories and 350 images in '../dataset/splitted\train\Golden Boy x Harold Brown'.
# There are 0 directories and 350 images in '../dataset/splitted\train\Harold Brown'.
# There are 0 directories and 350 images in '../dataset/splitted\train\Kearny'.

# %%
import matplotlib.pyplot as plt

def count_images_in_directories(base_path):
    directory_counts = {}
    for dirpath, dirnames, filenames in os.walk(base_path):
        if dirpath == base_path:
            # Skip the root directory
            continue
        directory_name = os.path.basename(dirpath)
        image_count = len(filenames)
        directory_counts[directory_name] = image_count
    return directory_counts

image_counts = count_images_in_directories(DATASET)
print(image_counts)

def plot_image_counts(base_path, output_file="image_counts.png"):
    # Count images in directories
    image_counts = count_images_in_directories(base_path)
    
    # Sort data for better visualization
    sorted_counts = dict(sorted(image_counts.items(), key=lambda item: item[1], reverse=True))
    
    
    # Extract data for the chart
    directories = list(sorted_counts.keys())
    counts = list(sorted_counts.values())
    
    # Plot horizontal bar chart
    plt.figure(figsize=(10, len(directories) * 0.4))  # Adjust height based on the number of directories
    plt.barh(directories, counts, color='skyblue')
    
    # Add labels and title
    plt.xlabel('Number of Classes')
    plt.ylabel('Classes')
    plt.title(f'Number of Classes {len(image_counts)}')
    
    # Display values on bars
    for index, value in enumerate(counts):
        plt.text(value, index, str(value), va='center')
    
    # Save the plot as PNG
    plt.tight_layout()
    plt.savefig(output_file, format="png", dpi=300)
    plt.close()  # Close the plot to free up memory
    
output_path = "class_count.png"  
plot_image_counts(DATASET, output_path)
print(f"Plot saved as '{output_path}'")
# Out:
# {'Gilmore': 500, 'Golden Boy': 500, 'Golden Boy x Gilmore': 500, 'Golden Boy x Harold Brown': 500, 'Harold Brown': 500, 'Kearny': 500}
# Plot saved as 'class_count.png'
